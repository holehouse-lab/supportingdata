# %% [markdown]
# # FUS phase diagrams
#
# * Fig. S5C
# * Fig. S5H

# %%
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
	
# Set such that PDF fonts export in a manner that they
# are editable in illustrator/affinity
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# set to define axes linewidths
matplotlib.rcParams['axes.linewidth'] = 0.5

# this defines some prefactors so inline figures look nice
# on a retina macbook. These can be commented out without any
# issue and are solely asthetic.
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# UPDATE 2020-12-31 (my preferred font is Avenir...)
font = {'family' : 'avenir',
    	'weight' : 'normal'}

matplotlib.rc('font', **font)

from finches import Mpipi_frontend, CALVADOS_frontend

mf = Mpipi_frontend()
cf = CALVADOS_frontend()

# starting at 259
from sparrow import Protein
fus_ntd      = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQY'
# Out:
# /Users/alex/Dropbox/WASHU/Holehouse/tools/finches/finches/finches/forcefields/calvados.py:235: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.038286503882254706' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   r.loc['H','q'] = 1. / ( 1 + 10**(self.pH-6) )

# %%
# build 6-E variant
sixE_pos = [26, 30, 68, 84, 87, 117]
wt_fus =  'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNS'
fus_12e = 'MASNDYEQQAEQSYGAYPEQPGQGYEQQSEQPYGQQSYSGYEQSTDTSGYGQSSYSSYGQEQNTGYGEQSTPQGYGSTGGYGSEQSEQSSYGQQSSYPGYGQQPAPSSTSGSYGSSEQSSSYGQPQSGSYEQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNS'

fus6E = list(wt_fus)
for p in sixE_pos:
    fus6E[p-1] = 'E'

fus6E = "".join(fus6E)
fusY2S = wt_fus.replace('Y','S')
print(fus6E)
print(fusY2S)
# Out:
# MASNDYTQQATQSYGAYPTQPGQGYEQQSEQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGEQSTPQGYGSTGGYGSEQSEQSSYGQQSSYPGYGQQPAPSSTSGSYGSSEQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNS
# MASNDSTQQATQSSGASPTQPGQGSSQQSSQPSGQQSSSGSSQSTDTSGSGQSSSSSSGQSQNTGSGTQSTPQGSGSTGGSGSSQSSQSSSGQQSSSPGSGQQPAPSSTSGSSGSSSQSSSSGQPQSGSSSQQPSSGGQQQSSGQQQSSNPPQGSGQQNQSNS

# %%
Protein(wt_fus).show_sequence(blocksize=50,newline=50)
Protein(fusY2S).show_sequence(blocksize=50,newline=50)
Protein(fus6E).show_sequence(blocksize=50,newline=50)
Protein(fus_12e).show_sequence(blocksize=50,newline=50)
# Out:
# <p style="font-family:Courier;font-size: 14px"><span style="color:#171616">M</span><span style="color:#171616">A</span><span style="color:#04700d">S</span><span style="color:#04700d">N</span><span style="color:#ff0d0d">D</span><span style="color:#ff9d00">Y</span><span style="color:#04700d">T</span><span style="color:#04700d">Q</span><span style="color:#04700d">Q</span><span style="color:#171616">A</span><span style="color:#04700d">T</span><span style="color:#04700d">Q</span><span style="color:#04700d">S</span><span style="color:#ff9d00">Y</span><span style="color:#04700d">G</span><span style="color:#171616">A</span><span style="color:#ff9d00">Y</span><span style="color:#cf30b7">P</span><span style="color:#04700d">T</span><span style="color:#04700d">Q</span><span style="color:#cf30b7">P</span><span style="color:#04700d">G</span><span style="color:#04700d">Q</span><span style="color:#04700d">G</span><span style="color:#ff9d00">Y</span><span style="color:#04700d">S</span><span style="co
# ...

# %%
mf.interaction_figure(wt_fus,wt_fus, window_size=31, tic_frequency=20, vmax=5, vmin=-5, fname='out_figures/fus_intermap.pdf')
mf.interaction_figure(fusY2S,fusY2S, window_size=31, tic_frequency=20, vmax=5, vmin=-5, fname='out_figures/fus_y2s_intermap.pdf')
mf.interaction_figure(fus6E,fus6E, window_size=31, tic_frequency=20, vmax=5, vmin=-5, fname='out_figures/fus_6E_intermap.pdf')
mf.interaction_figure(fus_12e,fus_12e, window_size=31, tic_frequency=20, vmax=5, vmin=-5, fname='out_figures/fus_12E_intermap.pdf')
# Out:
# (<Figure size 2975x2975 with 4 Axes>,
# ...
#  <Axes: >,
#  <Axes: >,
#  <Axes: >,
#  <Axes: >)

# %% [markdown]
# ## Fig. S5C

# %%
# Note we can ALSO plot the same diagram here directly from the frontend object

seqdict = {}
seqdict['FUS-WT'] = [wt_fus, 'blue']
seqdict['FUS-Y2S'] = [fusY2S, 'orange']
seqdict['FUS-12E'] = [fus_12e, 'red']
seqdict['FUS-6E']  = [fus6E, 'green']

# seqdict defines the sequences, names, and colors to be plotted
# tc_ref defines which sequence should be used as the critical temperature for reference to scale 
# rest of the options should be self explanatory - note the function is fully documented so read  
# the docstring for additional options!
B = mf.plot_multiple_phase_diagrams(seqdict, tc_ref='FUS-WT', ylim=[0.7, 1.05], height=2.5, width=3, filename='out_figures/fus_phase_diagram.pdf')

# %%
fus_5S1 = 'MASNDSTQQATQSSGASPTQPGQGSSQQSSQPSGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNSSSGGGGGGGGGGNYGQDQSSMSSGGGSGGGYGNQDQSGGGGSGGYGQQDRG'

fus_5S2 = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSSSGSSQSTDTSGSGQSSSSSSGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNSSSGGGGGGGGGGNYGQDQSSMSSGGGSGGGYGNQDQSGGGGSGGYGQQDRG'

fus_5S3 = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGSGTQSTPQGSGSTGGSGSSQSSQSSSGQQSSSPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNSSSGGGGGGGGGGNYGQDQSSMSSGGGSGGGYGNQDQSGGGGSGGYGQQDRG'

fus_5S4 = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGSGQQPAPSSTSGSSGSSSQSSSSGQPQSGSSSQQPSSGGQQQSYGQQQSYNPPQGYGQQNQYNSSSGGGGGGGGGGNYGQDQSSMSSGGGSGGGYGNQDQSGGGGSGGYGQQDRG'

fus_5S5 = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSSGQQQSSNPPQGSGQQNQSNSSSGGGGGGGGGGNSGQDQSSMSSGGGSGGGYGNQDQSGGGGSGGYGQQDRG'

fus_5S6 = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGSGQQNQSNSSSGGGGGGGGGGNSGQDQSSMSSGGGSGGGSGNQDQSGGGGSGGSGQQDRG'

fus_wt   = 'MASNDYTQQATQSYGAYPTQPGQGYSQQSSQPYGQQSYSGYSQSTDTSGYGQSSYSSYGQSQNTGYGTQSTPQGYGSTGGYGSSQSSQSSYGQQSSYPGYGQQPAPSSTSGSYGSSSQSSSYGQPQSGSYSQQPSYGGQQQSYGQQQSYNPPQGYGQQNQYNSSSGGGGGGGGGGNYGQDQSSMSSGGGSGGGYGNQDQSGGGGSGGYGQQDRG'


fus_seq_dict = {}

fus_seq_dict['fus_wt'] = [fus_wt, 'k']
fus_seq_dict['fus_5S1'] = [fus_5S1, 'r']
fus_seq_dict['fus_5S2'] = [fus_5S2, 'b']
fus_seq_dict['fus_5S3'] = [fus_5S3, 'g']
fus_seq_dict['fus_5S4'] = [fus_5S4, 'k']
fus_seq_dict['fus_5S5'] = [fus_5S5, 'purple']
fus_seq_dict['fus_5S6'] = [fus_5S6, 'orange']

# not they all fall on top of each other!
x=mf.plot_multiple_phase_diagrams(fus_seq_dict, width=0.9, xlim=[0.0001,0.1],xlog=True)

critical_ts = []
for i in range(len(fus_seq_dict)):
    critical_ts.append(x[0][i][2][1]/x[0][0][2][1])
# Out:
# /Users/alex/Dropbox/WASHU/Holehouse/tools/finches/finches/finches/frontend/frontend_base.py:1319: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Fig. S5H

# %%
figure(None, (3,2), dpi=450)
erro=22 # approximate uncertainity on measurements
plt.bar([1,2,3,4,5,6,7], critical_ts, color='k', alpha=0.4)
plt.xticks([1,2,3,4,5,6,7], ['WT', 'fus_5S1', 'fus_5S2', 'fus_5S3', 'fus_5S4', 'fus_5S5', 'fus_5S6'], rotation=45, fontsize=7)
plt.ylabel(r'$T_c/T_c^*$', fontsize=8)
plt.ylim([0.5, 1.1])
plt.yticks(fontsize=7)
plt.xticks(fontsize=7)
plt.tight_layout()
plt.savefig('out_figures/fus_variants_lin_currie_critT.pdf')
